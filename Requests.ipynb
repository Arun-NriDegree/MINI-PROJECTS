# %% [markdown]
# <a href="https://colab.research.google.com/github/Arun-NriDegree/MINI-PROJECTS/blob/main/Requests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# upload a CSV file
from google.colab import drive

# %%
drive. mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
# pandas-2 types-series, Dataframes
# series-[12,54,64,86,/]
# Dataframes-[]

# %%
dataset=pd.read_csv('/content/drive/Mydrive/Credit_Card_Applications
# Out:
#   File "<ipython-input-7-2da89e7d0af3>", line 1
#     dataset=pd.read_csv('/content/drive/Mydrive/Credit_Card_Applications
#                         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
#request - library in python - method/functions that enable user to perform CRUD operations
#with any server ir database or any source
#GET, POST, SET....
import requests

# %%
url = "https://jsonplaceholder.typicode.com/posts"

# %%
response = requests.get(url=url)

# %%
response.json()
# Out:
# [{'userId': 1,
#   'id': 1,
#   'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit',
#   'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'},
#  {'userId': 1,
#   'id': 2,
#   'title': 'qui est esse',
#   'body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla'},
#  {'userId': 1,
#   'id': 3,
#   'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut',
#   'body': 'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut'},
#  {'userId': 1,
#   'id': 4,
#   'title': 'eum et est occaecati',
# ...

# %%
type(response.json())
# Out:
# list

# %%
for _ in response.json():
  print(f'Post Number is {_["id"]}')
# Out:
# Post Number is 1
# Post Number is 2
# Post Number is 3
# Post Number is 4
# Post Number is 5
# Post Number is 6
# Post Number is 7
# Post Number is 8
# Post Number is 9
# Post Number is 10
# Post Number is 11
# Post Number is 12
# Post Number is 13
# Post Number is 14
# Post Number is 15
# Post Number is 16
# Post Number is 17
# Post Number is 18
# Post Number is 19
# Post Number is 20
# Post Number is 21
# Post Number is 22
# Post Number is 23
# Post Number is 24
# Post Number is 25
# Post Number is 26
# Post Number is 27
# Post Number is 28
# Post Number is 29
# Post Number is 30
# Post Number is 31
# Post Number is 32
# Post Number is 33
# Post Number is 34
# Post Number is 35
# Post Number is 36
# Post Number is 37
# Post Number is 38
# Post Number is 39
# Post Number is 40
# Post Number is 41
# Post Number is 42
# Post Number is 43
# Post Number is 44
# Post Number is 45
# Post Number is 46
# Post Number is 47
# Post Number is 48
# Post Number is 49
# Post Number is 50
# ...

# %%
url = 'https://api.github.com/search/repositories'

# %%
parms = {
     'q' : ' pandas+language:python',
     'sort' : ' stars',
     'order' : 'desc'
}

# %%
response = requests.get(url = url,params=parms)

# %%
response.json()
# Out:
# {'total_count': 658,
#  'incomplete_results': False,
#  'items': [{'id': 401964191,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk0MDE5NjQxOTE=',
#    'name': 'JigsawDataset',
#    'full_name': 'microsoft/JigsawDataset',
#    'private': False,
#    'owner': {'login': 'microsoft',
#     'id': 6154722,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYxNTQ3MjI=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/6154722?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/microsoft',
#     'html_url': 'https://github.com/microsoft',
#     'followers_url': 'https://api.github.com/users/microsoft/followers',
#     'following_url': 'https://api.github.com/users/microsoft/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/microsoft/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/microsoft/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/microsoft/subscriptions',
# ...
